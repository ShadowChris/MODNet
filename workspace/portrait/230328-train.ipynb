# %% [markdown]
# 训练代码参考:
# https://github.com/ZHKKKe/MODNet/issues/200
# https://www.kaggle.com/code/daggerx/modnet/notebook
# 预训练模型:
# https://drive.google.com/drive/folders/1umYmlCulvIFNaqPjwod1SayFmSRHziyR

# %%
import os
import torch
import shutil
from torch.utils.data import Dataset
from PIL import Image
import numpy as np
import pandas as pd
from scipy.ndimage.morphology import grey_dilation, grey_erosion
import torch.nn.functional as F
import torchvision.transforms as transforms
from scipy.ndimage import morphology
import cv2
from torch.utils.data import DataLoader
from src.models.modnet import MODNet
from src.trainer import supervised_training_iter
from tqdm import tqdm

# %%
os.chdir("../..")
print(os.getcwd())
dataset_path = "datasets/mini_matting_human_half"
ckpt_path = "pretrained/modnet_photographic_portrait_matting.ckpt"
# Out:
# E:\data\workspace\python\wanxiang-ai\MODNet

# %%
def cv2_imshow(image):

    # image = cv2.resize(image, (720, 480))

    cv2.imshow("img", image)
    #  add below code
    cv2.waitKey(0)
    cv2.destroyAllWindows()

import matplotlib
import matplotlib.pyplot as plt
def cv2plt(img):
    plt.figure(figsize=(7,7))        # To change the size of figure
    plt.axis('off')
    if np.size(img.shape) == 3:
        plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    else:
        plt.imshow(img,cmap='gray',vmin=0,vmax=255)
    plt.show()

print(cv2plt)
# Out:
# <function cv2plt at 0x000001F523D59158>

# %%
# 生成数据集pair
data_csv = pd.DataFrame(columns=["images", "matte"])
image_dir = os.path.abspath(dataset_path)
image_list = list()
for folder in os.listdir(image_dir):
#     if folder==".DS_Store":
#     continue
    for batch in os.listdir(os.path.join(image_dir, folder)):
        for clip in os.listdir(os.path.join(image_dir, folder, batch)):
            if clip=="._matting_00000000":
                continue
            for img in os.listdir(os.path.join(image_dir, folder, batch, clip)):
                # print(img)
                image = os.path.join(image_dir, folder, batch, clip, img)
                image_list.append(image)

data_csv["images"]=image_list
data_csv["matte"] = data_csv["images"]
data_csv["matte"] = data_csv["matte"].str.replace("jpg", "png").str.replace("clip_img", "matting").str.replace("clip_", "matting_")
data_csv
# Out:
#                                                 images  \
# 0    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 1    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 2    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 3    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 4    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# ..                                                 ...
# 921  E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 922  E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 923  E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 924  E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 925  E:\data\workspace\python\wanxiang-ai\MODNet\da...
#
#                                                  matte
# 0    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 1    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 2    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 3    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 4    E:\data\workspace\python\wanxiang-ai\MODNet\da...
# ..                                                 ...
# 921  E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 922  E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 923  E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 924  E:\data\workspace\python\wanxiang-ai\MODNet\da...
# 925  E:\data\workspace\python\wanxiang-ai\MODNet\da...
#
# [926 rows x 2 columns]

# %%
class ModNetDataLoader(Dataset):
    def __init__(self, annotations_file, resize_dim, transform=None):
        self.img_labels =annotations_file
        self.transform=transform
        self.resize_dim=resize_dim

    def __len__(self):
        #return the total number of images
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = self.img_labels.iloc[idx,0]
        mask_path = self.img_labels.iloc[idx,1]
        print(img_path)
        print(mask_path)

        img = np.asarray(Image.open(img_path))

        in_image = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)
        # cv2_imshow(in_image)

        mask = in_image[:,:,3]

        if len(img.shape)==2:
            img = img[:,:,None]
        if img.shape[2]==1:
            img = np.repeat(img, 3, axis=2)
        elif img.shape[2]==4:
            img = img[:,:,0:3]

        if len(mask.shape)==3:
            mask = mask[:,:, 0]

        #convert Image to pytorch tensor
        img = Image.fromarray(img)
        mask = Image.fromarray(mask)
        if self.transform:
            img = self.transform(img)
            trimap = self.get_trimap(mask)
            mask = self.transform(mask)

        img = self._resize(img)
        mask = self._resize(mask)
        trimap = self._resize(trimap, trimap=True)

        img = torch.squeeze(img, 0)
        mask = torch.squeeze(mask, 0)
        trimap = torch.squeeze(trimap, 1)

        return img, trimap, mask

    def get_trimap(self, alpha):
        # alpha \in [0, 1] should be taken into account
        # be careful when dealing with regions of alpha=0 and alpha=1
        fg = np.array(np.equal(alpha, 255).astype(np.float32))
        unknown = np.array(np.not_equal(alpha, 0).astype(np.float32)) # unknown = alpha > 0
        unknown = unknown - fg
        # image dilation implemented by Euclidean distance transform
        unknown = morphology.distance_transform_edt(unknown==0) <= np.random.randint(1, 20)
        trimap = fg
        trimap[unknown] = 0.5
        return torch.unsqueeze(torch.from_numpy(trimap), dim=0)#.astype(np.uint8)

    def _resize(self, img, trimap=False):
        im = img[None, :, :, :]
        ref_size = self.resize_dim

        # resize image for input
        im_b, im_c, im_h, im_w = im.shape
        if max(im_h, im_w) < ref_size or min(im_h, im_w) > ref_size:
            if im_w >= im_h:
                im_rh = ref_size
                im_rw = int(im_w / im_h * ref_size)
            elif im_w < im_h:
                im_rw = ref_size
                im_rh = int(im_h / im_w * ref_size)
        else:
            im_rh = im_h
            im_rw = im_w

        im_rw = im_rw - im_rw % 32
        im_rh = im_rh - im_rh % 32
        if trimap == True:
            im = F.interpolate(im, size=(im_rh, im_rw), mode='nearest')
        else:
            im = F.interpolate(im, size=(im_rh, im_rw), mode='area')
        return im

# %%
transformer = transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize((0.5), (0.5)
            )
        ]
    )
data = ModNetDataLoader(data_csv, 512, transform=transformer)

# %%
img, trimap, mask = data[4]
# 打印图像、matte 和 trimap 的形状
print("Image shape:", img.shape)
print("Trimap shape:", trimap.shape)
print("Matte shape:", mask.shape)
# Out:
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000008.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000008.png
# Image shape: torch.Size([3, 672, 512])
# Trimap shape: torch.Size([1, 672, 512])
# Matte shape: torch.Size([1, 672, 512])

# %%
# 展示图像
def img_transpose(img):
    return img.numpy().transpose(2,1,0).transpose(1,0,2)

img_t = img_transpose(img)
trimap_t = img_transpose(trimap)
mask_t = img_transpose(mask)

cv2plt(img_t)
cv2plt(trimap_t)
cv2plt(mask_t)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 训练加载器
train_dataloader = DataLoader(data, batch_size=2, shuffle=True)

# %%
import torch
import time
from src.models.modnet import MODNet
from src.trainer import supervised_training_iter
bs = 2         # batch size
lr = 0.01       # learn rate
epochs = 1     # total epochs
step_size = 10 # 学习率将在每 10 个 epoch 之后衰减
# step_size=int(0.25 * epochs)

# modnet = torch.nn.DataParallel(MODNet()).cuda()
modnet = torch.nn.DataParallel(MODNet(backbone_pretrained=True)).cuda()
optimizer = torch.optim.SGD(modnet.parameters(), lr=lr, momentum=0.9)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=0.1)

for epoch in range(0, epochs):
    start_time = time.time()
    total_loss = 0
    batch_count = 0
    for idx, (image, trimap, gt_matte) in enumerate(train_dataloader):
        semantic_loss, detail_loss, matte_loss = \
            supervised_training_iter(modnet, optimizer, image.cuda(), trimap.cuda(), gt_matte.cuda())
        total_loss += semantic_loss + detail_loss + matte_loss
        batch_count += 1
    end_time = time.time()
    avg_loss = total_loss / batch_count
    print(f"Epoch {epoch+1}/{epochs}, Avg Loss: {avg_loss:.4f}, Time: {end_time - start_time:.2f}s")
    lr_scheduler.step()

torch.save(modnet.state_dict(), "pretrained/my_train/modnet.ckpt")
# Out:
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000818.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000818.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000104.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000104.png
# E:\Anaconda\envs\modnet\lib\site-packages\torch\nn\functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# E:\Anaconda\envs\modnet\lib\site-packages\torch\nn\functional.py:3635: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000683.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000683.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000345.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000345.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000436.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000436.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000045.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000045.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000229.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000229.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000449.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000449.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000709.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000709.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000370.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000370.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000023.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000023.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000623.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000623.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000319.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000319.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000259.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000259.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000925.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000925.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000152.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000152.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000136.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000136.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000944.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000944.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000488.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000488.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000244.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000244.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000943.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000943.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000491.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000491.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000276.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000276.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000578.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000578.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000327.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000327.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000400.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000400.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000633.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000633.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000293.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000293.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000754.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000754.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000054.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000054.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000749.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000749.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000672.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000672.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000175.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000175.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000004.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000004.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000228.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000228.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000517.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000517.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000614.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000614.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000670.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000670.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000151.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000151.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000692.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000692.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000471.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000471.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000991.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000991.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000280.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000280.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000855.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000855.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000305.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000305.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000908.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000908.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000092.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000092.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000659.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000659.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000228.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000228.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000171.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000171.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000864.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000864.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000798.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000798.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000687.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000687.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000592.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000592.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000355.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000355.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000244.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000244.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000781.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000781.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000006.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000006.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000069.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000069.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000076.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000076.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000841.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000841.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000710.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000710.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000819.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000819.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000755.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000755.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000492.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000492.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000521.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000521.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000255.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000255.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000312.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000312.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000181.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000181.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000949.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000949.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000832.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000832.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000012.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000012.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000258.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000258.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000674.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000674.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000160.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000160.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000590.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000590.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\clip_img\1803151818\clip_00000000\1803151818-00000390.jpg
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000390.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00000093.png
# E:\data\workspace\python\wanxiang-ai\MODNet\datasets\mini_matting_human_half\matting\1803151818\matting_00000000\1803151818-00